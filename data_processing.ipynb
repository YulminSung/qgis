# %% [markdown]
# ## 기상데이터 불러오기

# %%
import pandas as pd

# 데이터 경로
data_path = 'data/weather_data/weather_day_data/강원도 기상데이터/'

# 기상데이터 리스트 만들기
weather_data = []

# 일 기상자료 데이터 불러오기
gangwon_1 = pd.read_csv(data_path + '강릉 기상청 데이터.csv', encoding='cp949')
gangwon_2 = pd.read_csv(data_path + '대관령 기상청 데이터.csv', encoding='cp949')
gangwon_3 = pd.read_csv(data_path + '동해 기상청 데이터.csv', encoding='cp949')
gangwon_4 = pd.read_csv(data_path + '북강릉 기상청 데이터.csv', encoding='cp949')
gangwon_5 = pd.read_csv(data_path + '북춘천 기상청 데이터.csv', encoding='cp949')
gangwon_6 = pd.read_csv(data_path + '속초 기상청 데이터.csv', encoding='cp949')
gangwon_7 = pd.read_csv(data_path + '영월 기상청 데이터.csv', encoding='cp949')
gangwon_8 = pd.read_csv(data_path + '원주 기상청 데이터.csv', encoding='cp949')
gangwon_9 = pd.read_csv(data_path + '인제 기상청 데이터.csv', encoding='cp949')
gangwon_10 = pd.read_csv(data_path + '정선군 기상청 데이터.csv', encoding='cp949')
gangwon_11 = pd.read_csv(data_path + '철원 기상청 데이터.csv', encoding='cp949')
gangwon_12 = pd.read_csv(data_path + '춘천 기상청 데이터.csv', encoding='cp949')
gangwon_13 = pd.read_csv(data_path + '태백 기상청 데이터.csv', encoding='cp949')
gangwon_14 = pd.read_csv(data_path + '홍천 기상청 데이터.csv', encoding='cp949')

# %%
#checking for total null values
gangwon_11.isnull().sum()
# Out:
# stnId           0
# stnNm           0
# tm              0
# avgTa           1
# minTa           0
#              ...
# sumLrgEv     1824
# sumSmlEv     1399
# n99Rn        2377
# iscs         3085
# sumFogDur    3568
# Length: 62, dtype: int64

# %% [markdown]
# ## 산림청 데이터 불러오기

# %%
import pandas as pd

# data path
data_path = 'data/forest_data/'

# 산불피해현황 data load
forest_data = pd.read_csv(data_path + '산림청 국립산림과학원_산불피해현황.csv', encoding='cp949')

forest_data.head(10)
# Out:
#    damagearea  endday  endmonth   endtime  endyear firecause  locbunji  \
# 0     1260.15       5         4  21:30:00     2019        기타      산171
# 1        1.00       5         4  20:00:00     2019    주택화재비화  512-1(임)
# 2        0.15       6         4  16:00:00     2019     입산자실화       산56
# 3        2.00       6         4  22:00:00     2019        기타       산79
# 4        1.02       7         4   8:40:00     2019     입산자실화      산163
# 5        0.10       8         4  16:44:00     2019     쓰레기소각     산38-1
# 6        0.06       8         4  15:10:00     2019        기타     산55-1
# 7        0.01       7         4  14:35:00     2019     입산자실화     산52-1
# 8        0.10       4         4  23:00:00     2019        기타       산42
# 9        0.10       6         4  13:20:00     2019        기타      산247
#
#   locdong locgungu locmenu locsi  startday startdayofweek  startmonth  \
# 0      남양       강릉      옥계    강원         4            목요일           4
# ...
